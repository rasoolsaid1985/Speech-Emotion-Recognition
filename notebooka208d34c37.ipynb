# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# # ****# ##Loading Libraries

# %%
import numpy as np
import pandas as pd
import os
import seaborn as sns
import matplotlib.pyplot as plt
import librosa
import librosa.display
from IPython.display import Audio
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # ****# ###Loading Dataset

# %%
path = []
labels = []
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        path.append(os.path.join(dirname, filename))
        label=filename.split('_')[-1]
#         print(label)
        label = label.split('.')[0]
#         print(label)
        labels.append(label.lower())
print("Dataset is ready")
# You can write up to 20GB to the current direct
# Out:
# Dataset is ready

# %%
path[:5]
# Out:
# ['/kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_fear/YAF_home_fear.wav',
#  '/kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_fear/YAF_youth_fear.wav',
#  '/kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_fear/YAF_near_fear.wav',
#  '/kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_fear/YAF_search_fear.wav',
#  '/kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_fear/YAF_pick_fear.wav']

# %%
labels[:5]
# Out:
# ['fear', 'fear', 'fear', 'fear', 'fear']

# %% [markdown]
# Create a dataframe

# %%
df = pd.DataFrame()
df['speech'] = path
df['label'] = labels

# %%
df.head()
# Out:
#                                               speech label
# 0  /kaggle/input/toronto-emotional-speech-set-tes...  fear
# 1  /kaggle/input/toronto-emotional-speech-set-tes...  fear
# 2  /kaggle/input/toronto-emotional-speech-set-tes...  fear
# 3  /kaggle/input/toronto-emotional-speech-set-tes...  fear
# 4  /kaggle/input/toronto-emotional-speech-set-tes...  fear

# %%
df['label'].value_counts()
# Out:
# label
# fear       800
# angry      800
# disgust    800
# neutral    800
# sad        800
# ps         800
# happy      800
# Name: count, dtype: int64

# %% [markdown]
# # # ###Exploratory Data Analysis****

# %%
sns.countplot(x='label', data=df)
# Out:
# <Axes: xlabel='label', ylabel='count'>

# %%
def waveplot(data, sr, emotion):
    plt.figure(figsize=(10, 4))
    plt.title(emotion, size=18)
    librosa.display.waveshow(data, sr=sr)
    plt.show()
    
def spectogram(data, sr, emotion):
    x = librosa.stft(data)  # Short-Time Fourier Transform (STFT)
    xdb = librosa.amplitude_to_db(abs(x))  # Convert amplitude to decibels
    plt.figure(figsize=(10, 4))
    plt.title(emotion, size=18)
    librosa.display.specshow(xdb, sr=sr, x_axis='time', y_axis='hz')  # Display spectrogram
    plt.colorbar()  # Add colorbar to indicate intensity
    plt.show()

# %%
emotion = 'fear'
path = df['speech'][df['label']==emotion][0]
data, sampling_rate = librosa.load(path)
waveplot(data,sampling_rate, emotion)
spectogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
emotion = 'angry'
path = np.array(df['speech'][df['label']==emotion])[0]
data, sampling_rate = librosa.load(path)
waveplot(data,sampling_rate, emotion)
spectogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
emotion = 'happy'
path = np.array(df['speech'][df['label']==emotion])[1]
data, sampling_rate = librosa.load(path)
waveplot(data,sampling_rate, emotion)
spectogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
emotion = 'disgust'
path = np.array(df['speech'][df['label']==emotion])[1]
data, sampling_rate = librosa.load(path)
waveplot(data,sampling_rate, emotion)
spectogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
emotion = 'sad'
path = np.array(df['speech'][df['label']==emotion])[0]
data, sampling_rate = librosa.load(path)
waveplot(data,sampling_rate, emotion)
spectogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
emotion = 'ps'
path = np.array(df['speech'][df['label']==emotion])[0]
data, sampling_rate = librosa.load(path)
waveplot(data,sampling_rate, emotion)
spectogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
emotion = 'neutral'
path = np.array(df['speech'][df['label']==emotion])[0]
data, sampling_rate = librosa.load(path)
waveplot(data,sampling_rate, emotion)
spectogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # ****# Feature Extraction using MFCC

# %%
def extract_mfcc(filename):
    y, sr = librosa.load(filename, duration=3, offset=0.5)
    mfcc = np.mean(librosa.feature.mfcc(y=y, sr=sr, n_mfcc=40).T, axis=0)
    return mfcc

# %%
extract_mfcc(df['speech'][0])
# Out:
# array([-285.73727  ,   85.78295  ,   -2.1689117,   22.125532 ,
#         -14.757396 ,   11.051347 ,   12.412449 ,   -3.000262 ,
#           1.0844985,   11.078271 ,  -17.41966  ,   -8.093213 ,
#           6.5879736,   -4.2209525,   -9.15508  ,    3.5214796,
#         -13.186381 ,   14.078853 ,   19.66973  ,   22.725618 ,
#          32.57464  ,   16.325033 ,   -3.8427284,    0.8962967,
#         -11.239264 ,    6.653461 ,   -2.5883694,   -7.7140164,
#         -10.941657 ,   -2.4007552,   -5.2812862,    4.271157 ,
#         -11.202216 ,   -9.024621 ,   -3.666985 ,    4.8697433,
#          -1.6027987,    2.5600514,   11.454374 ,   11.233449 ],
#       dtype=float32)

# %%
X_mfcc = df['speech'].apply(lambda x: extract_mfcc(x))

# %%
X_mfcc
# Out:
# 0       [-285.73727, 85.78295, -2.1689117, 22.125532, ...
# 1       [-348.34332, 35.193233, -3.8413284, 14.658875,...
# 2       [-340.11435, 53.796444, -14.267782, 20.884031,...
# 3       [-306.63422, 21.259708, -4.4110823, 6.4871554,...
# 4       [-344.7548, 46.329193, -24.171413, 19.392921, ...
#                               ...
# 5595    [-374.3952, 60.864998, 0.02505877, 8.431058, -...
# 5596    [-313.96478, 39.847843, -5.6493053, -3.8675754...
# 5597    [-357.54886, 77.88605, -15.224756, 2.194633, -...
# 5598    [-353.1474, 101.68391, -14.175897, -12.037376,...
# 5599    [-389.4595, 54.042767, 1.3469982, -1.4258989, ...
# Name: speech, Length: 5600, dtype: object

# %%
X = [x for x in X_mfcc]
X = np.array(X)
X.shape
# Out:
# (5600, 40)

# %%
#input split
X = np.expand_dims(X, -1)
X.shape
# Out:
# (5600, 40, 1)

# %%
from sklearn.preprocessing import OneHotEncoder
enc = OneHotEncoder()
y = enc.fit_transform(df[['label']])
y=y.toarray()

# %%
y.shape
# Out:
# (5600, 7)

# %% [markdown]
# # ****# LSTM Model

# %%
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout

model = Sequential([
    LSTM(123, return_sequences=False, input_shape=(40,1)),
    Dense(64, activation='relu'),
    Dropout(0.2),
    Dense(32, activation='relu'),
    Dropout(0.2),
    Dense(7, activation='softmax')
         ])

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_3 (LSTM)                   │ (None, 123)            │        61,500 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 64)             │         7,936 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 7)              │           231 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 71,747 (280.26 KB)
#  Trainable params: 71,747 (280.26 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
history = model.fit(X,y, validation_split=0.2, epochs=100, batch_size=512, shuffle=True)
# Out:
# Epoch 1/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 6s 327ms/step - accuracy: 0.2470 - loss: 1.8659 - val_accuracy: 0.2080 - val_loss: 1.9051
# Epoch 2/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 252ms/step - accuracy: 0.5043 - loss: 1.5757 - val_accuracy: 0.1437 - val_loss: 1.8099
# Epoch 3/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 244ms/step - accuracy: 0.6423 - loss: 1.1981 - val_accuracy: 0.1545 - val_loss: 1.6888
# Epoch 4/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 245ms/step - accuracy: 0.7305 - loss: 0.7952 - val_accuracy: 0.3500 - val_loss: 1.3588
# Epoch 5/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 244ms/step - accuracy: 0.7764 - loss: 0.6222 - val_accuracy: 0.5973 - val_loss: 0.9836
# Epoch 6/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 250ms/step - accuracy: 0.8442 - loss: 0.4664 - val_accuracy: 0.7821 - val_loss: 0.6484
# Epoch 7/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 246ms/step - accuracy: 0.8811 - loss: 0.3723 - val_accuracy: 0.8991 - val_loss: 0.4142
# Epoch 8/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 244ms/step - accuracy: 0.9137 - loss: 0.2758 - val_accuracy: 0.9241 - val_loss: 0.3022
# Epoch 9/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 244ms/step - accuracy: 0.9336 - loss: 0.2203 - val_accuracy: 0.9571 - val_loss: 0.1681
# Epoch 10/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 245ms/step - accuracy: 0.9518 - loss: 0.1683 - val_accuracy: 0.9616 - val_loss: 0.1420
# Epoch 11/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 249ms/step - accuracy: 0.9638 - loss: 0.1273 - val_accuracy: 0.9464 - val_loss: 0.1617
# Epoch 12/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 243ms/step - accuracy: 0.9571 - loss: 0.1316 - val_accuracy: 0.9473 - val_loss: 0.1645
# Epoch 13/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 243ms/step - accuracy: 0.9621 - loss: 0.1360 - val_accuracy: 0.9688 - val_loss: 0.1007
# Epoch 14/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 244ms/step - accuracy: 0.9688 - loss: 0.1007 - val_accuracy: 0.9759 - val_loss: 0.1015
# Epoch 15/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 275ms/step - accuracy: 0.9703 - loss: 0.1017 - val_accuracy: 0.9598 - val_loss: 0.1423
# Epoch 16/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 260ms/step - accuracy: 0.9750 - loss: 0.0881 - val_accuracy: 0.9750 - val_loss: 0.0790
# Epoch 17/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 244ms/step - accuracy: 0.9803 - loss: 0.0725 - val_accuracy: 0.9723 - val_loss: 0.0814
# Epoch 18/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 244ms/step - accuracy: 0.9788 - loss: 0.0697 - val_accuracy: 0.9786 - val_loss: 0.0667
# Epoch 19/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 250ms/step - accuracy: 0.9806 - loss: 0.0672 - val_accuracy: 0.9732 - val_loss: 0.0766
# Epoch 20/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 247ms/step - accuracy: 0.9828 - loss: 0.0580 - val_accuracy: 0.9795 - val_loss: 0.0613
# Epoch 21/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 246ms/step - accuracy: 0.9852 - loss: 0.0565 - val_accuracy: 0.9786 - val_loss: 0.0692
# Epoch 22/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 244ms/step - accuracy: 0.9857 - loss: 0.0533 - val_accuracy: 0.9884 - val_loss: 0.0373
# Epoch 23/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 244ms/step - accuracy: 0.9867 - loss: 0.0475 - val_accuracy: 0.9875 - val_loss: 0.0327
# Epoch 24/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 250ms/step - accuracy: 0.9845 - loss: 0.0497 - val_accuracy: 0.9741 - val_loss: 0.0884
# Epoch 25/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 245ms/step - accuracy: 0.9828 - loss: 0.0510 - val_accuracy: 0.9884 - val_loss: 0.0422
# Epoch 26/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 243ms/step - accuracy: 0.9883 - loss: 0.0443 - val_accuracy: 0.9830 - val_loss: 0.0506
# Epoch 27/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 242ms/step - accuracy: 0.9895 - loss: 0.0412 - val_accuracy: 0.9848 - val_loss: 0.0398
# Epoch 28/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 247ms/step - accuracy: 0.9893 - loss: 0.0384 - val_accuracy: 0.9812 - val_loss: 0.0448
# Epoch 29/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 263ms/step - accuracy: 0.9877 - loss: 0.0400 - val_accuracy: 0.9670 - val_loss: 0.0863
# Epoch 30/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 257ms/step - accuracy: 0.9852 - loss: 0.0485 - val_accuracy: 0.9893 - val_loss: 0.0307
# Epoch 31/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 243ms/step - accuracy: 0.9869 - loss: 0.0404 - val_accuracy: 0.9866 - val_loss: 0.0315
# Epoch 32/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 248ms/step - accuracy: 0.9871 - loss: 0.0382 - val_accuracy: 0.9920 - val_loss: 0.0257
# Epoch 33/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 242ms/step - accuracy: 0.9895 - loss: 0.0311 - val_accuracy: 0.9821 - val_loss: 0.0575
# Epoch 34/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 244ms/step - accuracy: 0.9902 - loss: 0.0366 - val_accuracy: 0.9884 - val_loss: 0.0332
# Epoch 35/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 244ms/step - accuracy: 0.9928 - loss: 0.0256 - val_accuracy: 0.9937 - val_loss: 0.0172
# Epoch 36/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 243ms/step - accuracy: 0.9931 - loss: 0.0224 - val_accuracy: 0.9884 - val_loss: 0.0262
# Epoch 37/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 250ms/step - accuracy: 0.9928 - loss: 0.0259 - val_accuracy: 0.9804 - val_loss: 0.0459
# Epoch 38/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 244ms/step - accuracy: 0.9907 - loss: 0.0295 - val_accuracy: 0.9884 - val_loss: 0.0300
# Epoch 39/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 243ms/step - accuracy: 0.9926 - loss: 0.0210 - val_accuracy: 0.9875 - val_loss: 0.0289
# Epoch 40/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 246ms/step - accuracy: 0.9917 - loss: 0.0282 - val_accuracy: 0.9875 - val_loss: 0.0317
# Epoch 41/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 249ms/step - accuracy: 0.9914 - loss: 0.0301 - val_accuracy: 0.9937 - val_loss: 0.0183
# Epoch 42/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 246ms/step - accuracy: 0.9943 - loss: 0.0204 - val_accuracy: 0.9946 - val_loss: 0.0163
# Epoch 43/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 262ms/step - accuracy: 0.9933 - loss: 0.0192 - val_accuracy: 0.9875 - val_loss: 0.0337
# Epoch 44/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 258ms/step - accuracy: 0.9959 - loss: 0.0149 - val_accuracy: 0.9929 - val_loss: 0.0180
# Epoch 45/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 245ms/step - accuracy: 0.9955 - loss: 0.0155 - val_accuracy: 0.9929 - val_loss: 0.0146
# Epoch 46/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 246ms/step - accuracy: 0.9962 - loss: 0.0136 - val_accuracy: 0.9973 - val_loss: 0.0068
# Epoch 47/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 247ms/step - accuracy: 0.9963 - loss: 0.0108 - val_accuracy: 0.9920 - val_loss: 0.0219
# Epoch 48/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 245ms/step - accuracy: 0.9974 - loss: 0.0111 - val_accuracy: 0.9964 - val_loss: 0.0135
# Epoch 49/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 243ms/step - accuracy: 0.9956 - loss: 0.0138 - val_accuracy: 0.9929 - val_loss: 0.0167
# Epoch 50/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 251ms/step - accuracy: 0.9960 - loss: 0.0112 - val_accuracy: 0.9929 - val_loss: 0.0203
# Epoch 51/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 245ms/step - accuracy: 0.9946 - loss: 0.0174 - val_accuracy: 0.9964 - val_loss: 0.0097
# Epoch 52/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 247ms/step - accuracy: 0.9974 - loss: 0.0121 - val_accuracy: 0.9902 - val_loss: 0.0217
# Epoch 53/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 246ms/step - accuracy: 0.9964 - loss: 0.0123 - val_accuracy: 0.9991 - val_loss: 0.0031
# Epoch 54/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 246ms/step - accuracy: 0.9986 - loss: 0.0077 - val_accuracy: 0.9991 - val_loss: 0.0040
# Epoch 55/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 247ms/step - accuracy: 0.9982 - loss: 0.0065 - val_accuracy: 0.9982 - val_loss: 0.0042
# Epoch 56/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 256ms/step - accuracy: 0.9990 - loss: 0.0055 - val_accuracy: 0.9982 - val_loss: 0.0043
# Epoch 57/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 256ms/step - accuracy: 0.9998 - loss: 0.0037 - val_accuracy: 0.9982 - val_loss: 0.0031
# Epoch 58/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 282ms/step - accuracy: 0.9987 - loss: 0.0052 - val_accuracy: 0.9991 - val_loss: 0.0032
# Epoch 59/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 250ms/step - accuracy: 0.9989 - loss: 0.0058 - val_accuracy: 1.0000 - val_loss: 0.0013
# Epoch 60/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 244ms/step - accuracy: 0.9999 - loss: 0.0030 - val_accuracy: 0.9991 - val_loss: 0.0032
# Epoch 61/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 243ms/step - accuracy: 0.9986 - loss: 0.0052 - val_accuracy: 0.9937 - val_loss: 0.0147
# Epoch 62/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 245ms/step - accuracy: 0.9971 - loss: 0.0107 - val_accuracy: 0.9973 - val_loss: 0.0034
# Epoch 63/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 245ms/step - accuracy: 0.9943 - loss: 0.0226 - val_accuracy: 0.9991 - val_loss: 0.0028
# Epoch 64/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 241ms/step - accuracy: 0.9947 - loss: 0.0154 - val_accuracy: 0.9937 - val_loss: 0.0172
# Epoch 65/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 248ms/step - accuracy: 0.9983 - loss: 0.0077 - val_accuracy: 0.9982 - val_loss: 0.0081
# Epoch 66/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 251ms/step - accuracy: 0.9982 - loss: 0.0058 - val_accuracy: 0.9991 - val_loss: 0.0051
# Epoch 67/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 251ms/step - accuracy: 0.9984 - loss: 0.0060 - val_accuracy: 1.0000 - val_loss: 0.0020
# Epoch 68/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 248ms/step - accuracy: 0.9977 - loss: 0.0082 - val_accuracy: 0.9946 - val_loss: 0.0136
# Epoch 69/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 248ms/step - accuracy: 0.9966 - loss: 0.0093 - val_accuracy: 0.9964 - val_loss: 0.0083
# Epoch 70/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 245ms/step - accuracy: 0.9971 - loss: 0.0091 - val_accuracy: 0.9937 - val_loss: 0.0211
# Epoch 71/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 288ms/step - accuracy: 0.9942 - loss: 0.0218 - val_accuracy: 0.9964 - val_loss: 0.0162
# Epoch 72/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 249ms/step - accuracy: 0.9949 - loss: 0.0155 - val_accuracy: 0.9982 - val_loss: 0.0087
# Epoch 73/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 248ms/step - accuracy: 0.9964 - loss: 0.0140 - val_accuracy: 0.9991 - val_loss: 0.0038
# Epoch 74/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 251ms/step - accuracy: 0.9954 - loss: 0.0129 - val_accuracy: 0.9955 - val_loss: 0.0093
# Epoch 75/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 250ms/step - accuracy: 0.9977 - loss: 0.0115 - val_accuracy: 0.9973 - val_loss: 0.0068
# Epoch 76/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 248ms/step - accuracy: 0.9980 - loss: 0.0067 - val_accuracy: 0.9973 - val_loss: 0.0069
# Epoch 77/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 252ms/step - accuracy: 0.9972 - loss: 0.0077 - val_accuracy: 0.9973 - val_loss: 0.0051
# Epoch 78/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 253ms/step - accuracy: 0.9979 - loss: 0.0077 - val_accuracy: 0.9973 - val_loss: 0.0059
# Epoch 79/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 252ms/step - accuracy: 0.9975 - loss: 0.0083 - val_accuracy: 1.0000 - val_loss: 0.0014
# Epoch 80/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 248ms/step - accuracy: 0.9989 - loss: 0.0043 - val_accuracy: 1.0000 - val_loss: 0.0020
# Epoch 81/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 248ms/step - accuracy: 0.9997 - loss: 0.0031 - val_accuracy: 1.0000 - val_loss: 0.0011
# Epoch 82/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 248ms/step - accuracy: 0.9998 - loss: 0.0029 - val_accuracy: 1.0000 - val_loss: 7.0524e-04
# Epoch 83/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 271ms/step - accuracy: 0.9996 - loss: 0.0027 - val_accuracy: 1.0000 - val_loss: 5.2757e-04
# Epoch 84/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 267ms/step - accuracy: 0.9998 - loss: 0.0025 - val_accuracy: 1.0000 - val_loss: 0.0012
# Epoch 85/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 247ms/step - accuracy: 0.9997 - loss: 0.0026 - val_accuracy: 1.0000 - val_loss: 4.9304e-04
# Epoch 86/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 246ms/step - accuracy: 0.9993 - loss: 0.0026 - val_accuracy: 1.0000 - val_loss: 5.1807e-04
# Epoch 87/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 253ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 1.0000 - val_loss: 2.7465e-04
# Epoch 88/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 246ms/step - accuracy: 0.9999 - loss: 0.0015 - val_accuracy: 1.0000 - val_loss: 6.2125e-04
# Epoch 89/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 247ms/step - accuracy: 0.9999 - loss: 0.0016 - val_accuracy: 1.0000 - val_loss: 1.8107e-04
# Epoch 90/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 250ms/step - accuracy: 0.9993 - loss: 0.0022 - val_accuracy: 1.0000 - val_loss: 4.9992e-04
# Epoch 91/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 252ms/step - accuracy: 0.9996 - loss: 0.0020 - val_accuracy: 1.0000 - val_loss: 4.6035e-04
# Epoch 92/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 247ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 1.0000 - val_loss: 2.3375e-04
# Epoch 93/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 246ms/step - accuracy: 0.9999 - loss: 0.0015 - val_accuracy: 1.0000 - val_loss: 1.3293e-04
# Epoch 94/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 245ms/step - accuracy: 0.9999 - loss: 0.0017 - val_accuracy: 1.0000 - val_loss: 1.1959e-04
# Epoch 95/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 246ms/step - accuracy: 0.9991 - loss: 0.0025 - val_accuracy: 1.0000 - val_loss: 1.3875e-04
# Epoch 96/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 249ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 1.0000 - val_loss: 1.1844e-04
# Epoch 97/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 265ms/step - accuracy: 0.9999 - loss: 0.0012 - val_accuracy: 1.0000 - val_loss: 1.3858e-04
# Epoch 98/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 260ms/step - accuracy: 0.9996 - loss: 0.0012 - val_accuracy: 1.0000 - val_loss: 2.0881e-04
# Epoch 99/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 245ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 1.0000 - val_loss: 7.7410e-05
# Epoch 100/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 251ms/step - accuracy: 0.9999 - loss: 0.0014 - val_accuracy: 1.0000 - val_loss: 6.7806e-05

# %%
accuracy = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss'] 

epochs = list(range(100))

# %%
plt.plot(epochs, loss, label="Trained loss")
plt.plot(epochs, val_loss, label="Val loss")
plt.xlabel("epcohs")
plt.ylabel("Loss")
plt.legend()
plt.show()
